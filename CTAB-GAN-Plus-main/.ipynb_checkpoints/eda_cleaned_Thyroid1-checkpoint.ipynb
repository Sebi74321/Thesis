# %% [markdown]
# # Thyroid Disease Dataset – Exploratory Data Analysis (EDA)
#
# Focus:
# - Feature distributions
# - Missing (null) values

# %% [markdown]
# ## 1. Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

real_path = 'Real_Datasets/new-thyroid.csv'
df = pd.read_csv(real_path)

print('Dataset shape:', df.shape)
df.head()
# Out:
# Dataset shape: (215, 6)
#    T3_resin_uptake  Total_serum_thyroxin  Total_serum_triiodothyronine  \
# 0              107                  10.1                           2.2
# 1              113                   9.9                           3.1
# 2              127                  12.9                           2.4
# 3              109                   5.3                           1.6
# 4              105                   7.3                           1.5
#
#    Basal_TSH  Maximal_TSH  Class
# 0        0.9          2.7      1
# 1        2.0          5.9      1
# 2        1.4          0.6      1
# 3        1.4          1.5      1
# 4        1.5         -0.1      1

# %% [markdown]
# ## 2. Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   T3_resin_uptake               215 non-null    int64
#  1   Total_serum_thyroxin          215 non-null    float64
#  2   Total_serum_triiodothyronine  215 non-null    float64
#  3   Basal_TSH                     215 non-null    float64
#  4   Maximal_TSH                   215 non-null    float64
#  5   Class                         215 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 10.2 KB

# %% [markdown]
# ## 3. Missing Values

# %%
missing_abs = df.isna().sum().sort_values(ascending=False)
missing_pct = (df.isna().mean() * 100).sort_values(ascending=False)

missing_df = pd.DataFrame({
    'missing_count': missing_abs,
    'missing_percent': missing_pct
})

total_cells = df.shape[0] * df.shape[1]
total_missing = df.isna().sum().sum()

missing_percentage = (total_missing / total_cells) * 100
print("total missing values:", missing_percentage)

missing_df[missing_df.missing_count > 0].head(20)
# Out:
# total missing values: 0.0
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []

# %% [markdown]
# ## 4. Missing Values Plot

# %%
# plt.figure(figsize=(10,5))
# missing_pct[missing_pct > 0].plot(kind='bar')
# plt.ylabel('Missing (%)')
# plt.title('Missing Values per Column')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Numeric Distributions

# %%
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
for col in num_cols:
    plt.figure()
    df[col].dropna().hist(bins=30)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ## 6. Categorical Distributions

# %%
cat_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()
for col in cat_cols:
    plt.figure(figsize=(6,4))
    df[col].value_counts(dropna=False).head(20).plot(kind='bar')
    plt.title(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 7. Notes
# - Columns with high missingness may need imputation or removal
# - Highly skewed distributions may require transformation before GAN training
